# %% [markdown]
# # 03 — Generate Figure 2 panels (A–E)
#
# This notebook reproduces Figure 2 panels A–E **with the final, publishable formatting unchanged**.
#
# It runs `scripts/03_make_figure2.py`.

# %%
from pathlib import Path
import sys, subprocess, os

# --- locate repo root robustly ---
ROOT = Path.cwd()
if not (ROOT / "scripts").exists() and (ROOT.parent / "scripts").exists():
    ROOT = ROOT.parent
if not (ROOT / "scripts").exists():
    raise RuntimeError("Could not find repo root (missing ./scripts). Start Jupyter from the repo root or the notebooks/ folder.")
print("Repo root:", ROOT)
# Out:
# Repo root: /research_jude/rgs01_jude/groups/greengrp/home/spoudel1/GreenLab_Projects/Suresh/mini_review_STAMP/stamp_figures_repo

# %%
h5ad   = ROOT / "stamp_fig1_scanvi_outputs" / "fig1_scanvi_analyzed.h5ad"
outdir = ROOT / "figures" / "Figure2"
outdir.mkdir(parents=True, exist_ok=True)

cmd = [
    sys.executable, str(ROOT / "scripts" / "03_make_figure2.py"),
    "--h5ad", str(h5ad),
    "--outdir", str(outdir),
]
print("Running:", " ".join(cmd))
subprocess.run(cmd, check=True)

print("Saved panels in:", outdir)
# Out:
# Running: /home/spoudel1/.conda/envs/scvi-env_new/bin/python /research_jude/rgs01_jude/groups/greengrp/home/spoudel1/GreenLab_Projects/Suresh/mini_review_STAMP/stamp_figures_repo/scripts/03_make_figure2.py --h5ad /research_jude/rgs01_jude/groups/greengrp/home/spoudel1/GreenLab_Projects/Suresh/mini_review_STAMP/stamp_figures_repo/stamp_fig1_scanvi_outputs/fig1_scanvi_analyzed.h5ad --outdir /research_jude/rgs01_jude/groups/greengrp/home/spoudel1/GreenLab_Projects/Suresh/mini_review_STAMP/stamp_figures_repo/figures/Figure2
# /research_jude/rgs01_jude/groups/greengrp/home/spoudel1/GreenLab_Projects/Suresh/mini_review_STAMP/stamp_figures_repo/scripts/03_make_figure2.py:260: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = mix_obs.groupby(["fov", "scanvi_pred"]).size().unstack(fill_value=0)
# ...
